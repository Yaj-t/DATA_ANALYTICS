# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd
  
# fetch dataset 
online_shoppers_purchasing_intention_dataset = fetch_ucirepo(id=468) 
  
# data (as pandas dataframes) 
X = online_shoppers_purchasing_intention_dataset.data.features 
y = online_shoppers_purchasing_intention_dataset.data.targets 
  
# metadata 
print(online_shoppers_purchasing_intention_dataset.metadata) 
  
# variable information 
print(online_shoppers_purchasing_intention_dataset.variables)
# Out:
# {'uci_id': 468, 'name': 'Online Shoppers Purchasing Intention Dataset', 'repository_url': 'https://archive.ics.uci.edu/dataset/468/online+shoppers+purchasing+intention+dataset', 'data_url': 'https://archive.ics.uci.edu/static/public/468/data.csv', 'abstract': 'Of the 12,330 sessions in the dataset,\n84.5% (10,422) were negative class samples that did not\nend with shopping, and the rest (1908) were positive class\nsamples ending with shopping.', 'area': 'Business', 'tasks': ['Classification', 'Clustering'], 'characteristics': ['Multivariate'], 'num_instances': 12330, 'num_features': 17, 'feature_types': ['Integer', 'Real'], 'demographics': [], 'target_col': ['Revenue'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2018, 'last_updated': 'Thu Jan 11 2024', 'dataset_doi': '10.24432/C5F88Q', 'creators': ['C. Sakar', 'Yomi Kastro'], 'intro_paper': {'title': 'Real-time prediction of online shoppers’ purchasing intention using mul
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.countplot(data=data, x='Month', order=data['Month'].value_counts().index)
plt.title('Distribution of Month')

plt.subplot(1, 2, 2)
sns.countplot(data=data, x='VisitorType', order=data['VisitorType'].value_counts().index)
plt.title('Distribution of VisitorType')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(data=data, x='BounceRates', y='ExitRates', hue='Revenue', alpha=0.6)
plt.title('BounceRates vs. ExitRates colored by Revenue')

plt.subplot(1, 2, 2)
sns.scatterplot(data=data, x='ProductRelated', y='ProductRelated_Duration', hue='Revenue', alpha=0.6)
plt.title('ProductRelated vs. ProductRelated_Duration colored by Revenue')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
revenue_counts = data['Revenue'].value_counts()
plt.pie(revenue_counts, labels=revenue_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff9999'])
plt.title('Proportion of Sessions Resulting in Revenue')
plt.show()
